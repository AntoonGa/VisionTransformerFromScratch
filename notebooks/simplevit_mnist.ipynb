# %% [markdown]
# # Load data

# %%
import torch
from torch.utils.data import DataLoader
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(device)
torch.cuda.empty_cache()
torch.cuda.synchronize()

train_data_dir = r"../datasets/mnist/train"
valid_data_dir = r"../datasets/mnist/test"
# Out:
# cuda

# %%
import torchvision.transforms as transforms
from core.dataloaders.mnist import MnistDataset

# setting up transformation
transformation = transforms.Compose([
    transforms.ToTensor(),
])
type(transformation)
# creating dataset
train_dataset = MnistDataset(
    data_dir=train_data_dir,
    train = True,
    transform=transformation
)
valid_dataset = MnistDataset(
    data_dir=valid_data_dir,
    train = False,
    transform=transformation
)

classes = train_dataset.classes
print(classes)
# Out:
# Folder '../datasets/mnist/train' already exists.
# Folder '../datasets/mnist/test' already exists.
# ['0 - zero', '1 - one', '2 - two', '3 - three', '4 - four', '5 - five', '6 - six', '7 - seven', '8 - eight', '9 - nine']

# %%
# creating dataloader
from shared_modules.display_engine import DisplayImages
# creating dataloader
workers = 8
prefetch = workers * 12
train_dataloader = DataLoader(train_dataset,
                              batch_size=1024,
                              shuffle=True,
                              num_workers=workers,
                              prefetch_factor=prefetch,
                              persistent_workers=True,
                              pin_memory=False)
valid_dataloader = DataLoader(valid_dataset,
                              batch_size=256,
                              shuffle=False,
                              num_workers=workers,
                              prefetch_factor=prefetch,
                              persistent_workers=True,
                              pin_memory=False)

print("training set", len(train_dataloader.dataset))
print("valid set", len(valid_dataloader.dataset))

# iterating over the dataset
for _, (image, label) in enumerate(train_dataloader):
    print("shapes:")
    print(image.shape)
    print(label.shape)
    DisplayImages.display_image(image, label)
    break
# Out:
# training set 60000
# valid set 10000
# shapes:
# torch.Size([1024, 1, 28, 28])
# torch.Size([1024])

# %% [markdown]
# # Model

# %%
from core.classifier_models.simplevit import SimpleVitClassifier
model = SimpleVitClassifier()

# %%
# create optimizer and loss function
import torch.nn as nn
import torch.optim as optim
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.0001)

# %%
# create wrapper
from core.wrappers.wrapper import Wrapper
classifier = Wrapper(model = model, optimizer= optimizer, criterion= criterion, device = "cuda")

# %%
from torchinfo import summary
input_size = image.shape
summary(model=classifier.model,
        input_size=input_size,
        col_names=["input_size", "output_size", "num_params", "trainable"],
        col_width=20,
        row_settings=["var_names"])
# Out:
# ==================================================================================================================================
# Layer (type (var_name))                            Input Shape          Output Shape         Param #              Trainable
# ==================================================================================================================================
# SimpleVitClassifier (SimpleVitClassifier)          [1024, 1, 28, 28]    [1024, 10]           --                   True
# ├─SimpleViT (base_model)                           [1024, 1, 28, 28]    [1024, 10]           --                   True
# │    └─Sequential (to_patch_embedding)             [1024, 1, 28, 28]    [1024, 16, 256]      --                   True
# │    │    └─Rearrange (0)                          [1024, 1, 28, 28]    [1024, 16, 49]       --                   --
# │    │    └─LayerNorm (1)                          [1024, 16, 49]       [1024, 16, 49]       98                   True
# │    │    └─Linear (2)                             [1024, 16, 49]       [1024, 16, 256]      12,800               True
# │    │    └─LayerNorm (3)                          [1024, 16, 256]      [1024, 16, 256]      512                  True
# │    └─Transformer (transformer)                   [1024, 16, 256]      [1024, 16, 256]      --                   True
# │    │    └─ModuleList (layers)                    --                   --                   4,729,344            True
# │    │    └─LayerNorm (norm)                       [1024, 16, 256]      [1024, 16, 256]      512                  True
# │    └─Identity (to_latent)                        [1024, 256]          [1024, 256]          --                   --
# │    └─Linear (linear_head)                        [1024, 256]          [1024, 10]           2,570                True
# ==================================================================================================================================
# Total params: 4,745,836
# Trainable params: 4,745,836
# Non-trainable params: 0
# Total mult-adds (Units.GIGABYTES): 4.86
# ==================================================================================================================================
# Input size (MB): 3.21
# Forward/backward pass size (MB): 2523.09
# Params size (MB): 18.98
# Estimated Total Size (MB): 2545.28
# ==================================================================================================================================

# %%
# model accuracy pre training
predictions = classifier.predict_class(valid_dataloader)
print(predictions)
loss, acc = classifier.evaluate(valid_dataloader)
print(loss, acc)
for _, (image, label) in enumerate(valid_dataloader):
    class_pred = classifier.predict_class(image.to(device))
    print(class_pred)
    DisplayImages.display_image(image, label, class_pred, 6, 5)
    break
# Out:
# [8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 7, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8,  ...
# 2.3808051692962646 0.1011
# [8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 7, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 6, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8, 8]

# %% [markdown]
# # Training

# %%
num_epochs = 20
classifier.fit(epochs=num_epochs, train_dataloader = train_dataloader, valid_dataloader=valid_dataloader)
# Out:
# Epochs::   5%|▌         | 1/20 [00:05<01:37,  5.13s/it]
# | Epoch 1/20 | T-loss: 1.428 | V-loss: 0.871 |T-acc: 0.54 |V-acc: 0.73
# Epochs::  10%|█         | 2/20 [00:10<01:30,  5.05s/it]
# | Epoch 2/20 | T-loss: 0.620 | V-loss: 0.417 |T-acc: 0.81 |V-acc: 0.88
# Epochs::  15%|█▌        | 3/20 [00:15<01:25,  5.01s/it]
# | Epoch 3/20 | T-loss: 0.352 | V-loss: 0.297 |T-acc: 0.89 |V-acc: 0.91
# Epochs::  20%|██        | 4/20 [00:20<01:19,  5.00s/it]
# | Epoch 4/20 | T-loss: 0.249 | V-loss: 0.232 |T-acc: 0.93 |V-acc: 0.93
# Epochs::  25%|██▌       | 5/20 [00:25<01:14,  5.00s/it]
# | Epoch 5/20 | T-loss: 0.184 | V-loss: 0.188 |T-acc: 0.95 |V-acc: 0.94
# Epochs::  30%|███       | 6/20 [00:30<01:09,  4.99s/it]
# | Epoch 6/20 | T-loss: 0.152 | V-loss: 0.179 |T-acc: 0.95 |V-acc: 0.94
# Epochs::  35%|███▌      | 7/20 [00:35<01:04,  4.99s/it]
# | Epoch 7/20 | T-loss: 0.124 | V-loss: 0.162 |T-acc: 0.96 |V-acc: 0.95
# Epochs::  40%|████      | 8/20 [00:39<00:59,  4.98s/it]
# | Epoch 8/20 | T-loss: 0.101 | V-loss: 0.163 |T-acc: 0.97 |V-acc: 0.95
# Epochs::  45%|████▌     | 9/20 [00:44<00:54,  4.98s/it]
# | Epoch 9/20 | T-loss: 0.082 | V-loss: 0.136 |T-acc: 0.98 |V-acc: 0.96
# Epochs::  50%|█████     | 10/20 [00:49<00:49,  4.98s/it]
# | Epoch 10/20 | T-loss: 0.065 | V-loss: 0.132 |T-acc: 0.98 |V-acc: 0.96
# Epochs::  55%|█████▌    | 11/20 [00:54<00:44,  4.98s/it]
# | Epoch 11/20 | T-loss: 0.049 | V-loss: 0.134 |T-acc: 0.99 |V-acc: 0.96
# Epochs::  60%|██████    | 12/20 [00:59<00:39,  4.98s/it]
# | Epoch 12/20 | T-loss: 0.038 | V-loss: 0.142 |T-acc: 0.99 |V-acc: 0.96
# Epochs::  65%|██████▌   | 13/20 [01:04<00:34,  4.98s/it]
# | Epoch 13/20 | T-loss: 0.031 | V-loss: 0.132 |T-acc: 0.99 |V-acc: 0.96
# Epochs::  70%|███████   | 14/20 [01:09<00:29,  4.99s/it]
# | Epoch 14/20 | T-loss: 0.026 | V-loss: 0.135 |T-acc: 0.99 |V-acc: 0.96
# Epochs::  75%|███████▌  | 15/20 [01:14<00:24,  4.99s/it]
# | Epoch 15/20 | T-loss: 0.022 | V-loss: 0.138 |T-acc: 0.99 |V-acc: 0.96
# Epochs::  80%|████████  | 16/20 [01:19<00:19,  4.98s/it]
# | Epoch 16/20 | T-loss: 0.014 | V-loss: 0.137 |T-acc: 1.00 |V-acc: 0.96
# Epochs::  85%|████████▌ | 17/20 [01:24<00:14,  4.99s/it]
# | Epoch 17/20 | T-loss: 0.013 | V-loss: 0.142 |T-acc: 1.00 |V-acc: 0.96
# Epochs::  90%|█████████ | 18/20 [01:29<00:09,  4.99s/it]
# | Epoch 18/20 | T-loss: 0.009 | V-loss: 0.144 |T-acc: 1.00 |V-acc: 0.96
# Epochs::  95%|█████████▌| 19/20 [01:34<00:04,  4.99s/it]
# | Epoch 19/20 | T-loss: 0.006 | V-loss: 0.136 |T-acc: 1.00 |V-acc: 0.97
# Epochs:: 100%|██████████| 20/20 [01:39<00:00,  4.99s/it]
# | Epoch 20/20 | T-loss: 0.004 | V-loss: 0.138 |T-acc: 1.00 |V-acc: 0.97

# %%
# model accuracy post training
predictions = classifier.predict_class(valid_dataloader)
print(predictions)
loss, acc = classifier.evaluate(valid_dataloader)
print(loss, acc)
for _, (image, label) in enumerate(valid_dataloader):
    class_pred = classifier.predict_class(image.to(device))
    print(class_pred)
    DisplayImages.display_image(image, label, class_pred, 6, 5)
    break
# Out:
# [7, 2, 1, 0, 4, 1, 4, 9, 5, 9, 0, 6, 9, 0, 1, 5, 9, 7, 5, 4, 9, 6, 6, 5, 4, 0, 7, 4, 0, 1, 3, 1, 3, 4, 7, 2, 7, 1, 2, 1, 1, 7, 4, 2, 3, 5, 1, 2, 4, 4, 6, 3, 5, 5, 6, 0, 4, 1, 9, 5, 7, 2, 9, 3, 7, 4, 6, 4, 3, 0, 7, 0, 2, 9, 1, 7, 3, 2, 9, 7, 7, 6, 2, 7, 8, 4, 7, 3, 6, 1, 3, 6, 9, 3, 1, 4, 1, 7, 6, 9, 6, 0, 5, 4, 9, 9, 2, 1, 9, 4, 8, 7, 3, 9, 7, 4, 4, 4, 9, 
 9, 3, 4, 5, 5, 8, 7, 3, 7, 2, 7, 0, 2, 4, 1, 1, 6, 6, 9, 2, 8, 7, 2, 0, 1, 5, 0, 9, 1, 9, 0, 6, 0, 8, 6, 8, 1, 8, 0, 3, 3, 7, 2, 3, 6, 2, 1, 6, 1, 1, 3, 7, 9, 0, 8, 0, 5, 4, 0, 5, 8, 2, 2, 9, 8, 4, 0, 9, 5, 8, 5, 1, 2, 1, 3, 1, 7, 4, 5, 7, 2, 0, 3, 8, 8, 6, 2, 5, 4, 1, 9, 2, 1, 5, 8, 1, 0, 2, 9, 4, 3, 6, 8, 8, 2, 4, 0, 5, 0, 4, 4, 7, 9, 3, 4, 1, 5, 9, 7, 3, 5, 8, 8, 0, 5, 3, 3, 8, 6, 0, 1, 6, 0, 3, 7, 4, 4, 1, 2, 9, 1, 4, 6, 9, 9, 3, 9, 8, 4, 4, 3, 1, 3, 1, 8, 8, 7, 9, 4, 8, 6, 7, 9, 7, 1, 4, 5, 6,  ...
# 0.1377543843609281 0.9672
# [7, 2, 1, 0, 4, 1, 4, 9, 5, 9, 0, 6, 9, 0, 1, 5, 9, 7, 5, 4, 9, 6, 6, 5, 4, 0, 7, 4, 0, 1, 3, 1, 3, 4, 7, 2, 7, 1, 2, 1, 1, 7, 4, 2, 3, 5, 1, 2, 4, 4, 6, 3, 5, 5, 6, 0, 4, 1, 9, 5, 7, 2, 9, 3, 7, 4, 6, 4, 3, 0, 7, 0, 2, 9, 1, 7, 3, 2, 9, 7, 7, 6, 2, 7, 8, 4, 7, 3, 6, 1, 3, 6, 9, 3, 1, 4, 1, 7, 6, 9, 6, 0, 5, 4, 9, 9, 2, 1, 9, 4, 8, 7, 3, 9, 7, 4, 4, 4, 9, 2, 5, 4, 7, 6, 7, 9, 0, 5, 8, 5, 6, 6, 5, 7, 8, 1, 0, 1, 6, 4, 6, 7, 3, 1, 7, 1, 8, 2, 0, 3, 9, 8, 5, 5, 1, 5, 6, 0, 3, 4, 4, 6, 5, 4, 6, 5, 4, 5, 1, 4, 4, 7, 2, 3, 2, 7, 1, 8, 1, 8, 1, 8, 5, 0, 8, 9, 2, 5, 0, 1, 1, 1, 0, 9, 0, 3, 1, 6, 4, 2, 3, 6, 1, 1, 1, 3, 9, 5, 2, 9, 4, 5, 9, 3, 9, 0, 3, 6, 5, 5, 7, 2, 2, 7, 1, 2, 8, 4, 1, 7, 3, 3, 8, 8, 7, 9, 2, 2, 4, 1, 5, 9, 8, 7, 2, 3, 0, 6, 4, 2, 4, 1, 9, 5, 7, 7]

# %%
from shared_modules.display_engine import DisplayMetrics

DisplayMetrics.display_metrics(classifier.train_losses,
                               classifier.val_losses,
                               classifier.train_acc,
                               classifier.val_acc)

# %%
from shared_modules.display_engine import DisplayMetrics

labels = []
class_preds = []
for _, (image, label) in enumerate(valid_dataloader):
    class_pred = classifier.predict_class(image.to(device))
    labels.extend(label.numpy())
    class_preds.extend(class_pred)

DisplayMetrics.confusion_matrix(labels, class_preds, (20, 20))
DisplayMetrics.prediction_distribution(labels, class_preds, (20, 20))
